# %%
import json
import pandas as pd

from dateutil.parser import parse as date_parse

# %%
data_path = './data/neo4j_graph/politicians_200907.json'

# %%
with open(data_path, 'r') as f:
    data = json.load(f)

# %%
following_relationship = data[0]
user_information = data[1]
category_information = data[2]

# %% [markdown]
# # to csv

# %% [markdown]
# Neo4jの「import tool」を使ってcsvファイルを読み込む場合、リレーションシップの始点と終点を指定するためのノードIDを用意する必要があります。ノードIDはすべてのノードに関して一意でなければなりません。ここではユーザノードはツィッターが用意しているユーザIDを用いるが、カテゴリとグループに関しては一意のIDを生成します。

# %% [markdown]
# ## nodes

# %% [markdown]
# ### category and group

# %% [markdown]
# カテゴリーとグループのリストを出します。

# %%
categories = list(set(c[0] for c in category_information))
groups = list(set([c[1] for c in category_information]))

# %% [markdown]
# 後でリレーションシップを構築するためにカテゴリ・グループ名とIDの辞書を用意します

# %%
category_name_to_id = {c: 'category_{}'.format(i) for i,c in enumerate(categories)}
group_name_to_id = {g: 'group_{}'.format(i) for i,g in enumerate(groups)}

# category_df = pd.DataFrame(category_name_to_id.items(), columns=['categoryId:ID', 'name'])
# group_df = pd.DataFrame(group_name_to_id.items(), columns=['groupId:ID', 'name'])

category_df = pd.DataFrame(category_name_to_id.items(), columns=['name', ':ID'])
group_df = pd.DataFrame(group_name_to_id.items(), columns=['name', ':ID'])

# %%
category_df[':LABEL'] = 'CATEGORY'
category_df
# Out:
#      name         :ID    :LABEL
# 0  政治家・議員  category_0  CATEGORY

# %%
group_df[':LABEL'] = 'GROUP'
group_df.head()
# Out:
#         name      :ID :LABEL
# 0  日本を元気にする会  group_0  GROUP
# 1   都知事選2016  group_1  GROUP
# 2        民進党  group_2  GROUP
# 3     日本維新の会  group_3  GROUP
# 4      日本の政党  group_4  GROUP

# %%
category_df.to_csv('./data/neo4j_graph/politician_category_node.csv', index=False)
group_df.to_csv('./data/neo4j_graph/politician_group_node.csv', index=False)

# %% [markdown]
# ### user

# %%
def parse_user_feed(user_info):
    user_parse = {}
    for feed in ['id', 
                 'name', 
                 'screen_name', 
                 'location', 
                 'description', 
                 'protected', 
                 'followers_count', 
                 'friends_count', 
                 'listed_count', 
                 'created_at']:
        user_parse[feed] = user_info.get(feed)
        if feed == 'created_at' and user_info.get(feed):
            user_parse[feed] = date_parse(user_parse[feed])
        if 'count' in feed:
            if user_parse[feed]:
                user_parse[feed] = int(user_parse[feed])
    return user_parse

# %%
user_information_parsed = [parse_user_feed(u) for u in user_information]
users_with_information = set([u['id'] for u in user_information])

# %%
len(users_with_information)
# Out:
# 347

# %%
users_in_relationship = []
for i, v in following_relationship.items():
    users_in_relationship += v

# %%
users_without_information = list(set(users_in_relationship) - set(users_with_information))

# %%
print(len(users_without_information), len(set(users_in_relationship)), len(users_with_information))
print(len(users_without_information) - len(set(users_in_relationship)), len(users_with_information))
print(set(users_without_information) & set(users_with_information))
# Out:
# 282636 282982 347
# -346 347
# set()

# %%
user_information_parsed_no_info = [parse_user_feed({'id': u}) for u in users_without_information]

# %%
user_df = pd.DataFrame(user_information_parsed+user_information_parsed_no_info)

# %% [markdown]
# #### debug

# %%
fc = user_df.followers_count

# %%
fc_list = []
for x in fc.to_list():
    if pd.isnull(x):
        fc_list.append(None)
    else:
        fc_list.append(int(x))

# %%
pd.DataFrame(fc_list)
# Out:
#                0
# 0         2663.0
# 1         4107.0
# 2         2313.0
# 3       258141.0
# 4         6671.0
# ...          ...
# 282978       NaN
# 282979       NaN
# 282980       NaN
# 282981       NaN
# 282982       NaN
#
# [282983 rows x 1 columns]

# %%
fc_list[:3]
# Out:
# [2663, 4107, 2313]

# %%
fc.apply(lambda x: int(x) if not pd.isnull(x) else x)
# Out:
# 0           2663.0
# 1           4107.0
# 2           2313.0
# 3         258141.0
# 4           6671.0
#             ...
# 282978         NaN
# 282979         NaN
# 282980         NaN
# 282981         NaN
# 282982         NaN
# Name: followers_count, Length: 282983, dtype: float64

# %%
fc.astype(int, errors='ignore')
# Out:
# 0           2663.0
# 1           4107.0
# 2           2313.0
# 3         258141.0
# 4           6671.0
#             ...
# 282978         NaN
# 282979         NaN
# 282980         NaN
# 282981         NaN
# 282982         NaN
# Name: followers_count, Length: 282983, dtype: float64

# %% [markdown]
# #### continue user

# %%
print(user_df.shape)
# Out:
# (282983, 10)

# %%
user_df.head()
# Out:
#                    id                   name      screen_name  \
# 0            99227667                  米田　貴志    yonedatakashi
# 1           141513987     前衆議院議員・いさか信彦（兵庫１区）    isakanobuhiko
# 2  911542923333820416  山川ゆりこ《立憲民主党 りっけん 埼玉3区  yamakawa_yuriko
# 3            12392332                  家入 一真             hbkr
# 4            43028151                   吉田雄人      YoshidaYuto
#
#                       location  \
# 0                      大阪府岸和田市
# 1  兵庫県神戸市中央区八幡通4-2-14トロア神戸ビル4F
# 2                   埼玉 草加市・越谷市
# 3
# 4
#
#                                          description protected  \
# 0  公明党岸和田市議会議員です。平成19年4月に初当選させて頂きました。市民を守る豊かな財政力を...     False
# 1  前衆議院議員・井坂信彦（神戸市中央区・灘区・東灘区）のtwitterです。本人およびスタッフ...     False
# 2  埼玉３区（草加市・越谷市）の衆議院議員です。山川ゆりこは一貫して「武力によらない平和をつくる...     False
# 3  金融包摂をつくる。CAMPFIRE代表取締役。BASE共同創業取締役。NOW, XIMERA...     False
# 4                    Glocal Government Relationz株式会社     False
#
#    followers_count  friends_count  listed_count                created_at
# 0           2663.0         2455.0         216.0 2009-12-25 05:45:31+00:00
# 1           4107.0         2382.0         253.0 2010-05-08 08:23:24+00:00
# 2           2313.0          104.0          89.0 2017-09-23 10:49:03+00:00
# 3         258141.0         4020.0        4566.0 2008-01-18 09:01:26+00:00
# 4           6671.0         3117.0         530.0 2009-05-28 02:32:22+00:00

# %%
user_df.columns
# Out:
# Index(['id', 'name', 'screen_name', 'location', 'description', 'protected',
#        'followers_count', 'friends_count', 'listed_count', 'created_at'],
#       dtype='object')

# %% [markdown]
# # 問題
# - datetime形式
# - 文字コード

# %%
user_df.drop(columns=['created_at', 'description'])
# Out:
#                         id                   name      screen_name  \
# 0                 99227667                  米田　貴志    yonedatakashi
# 1                141513987     前衆議院議員・いさか信彦（兵庫１区）    isakanobuhiko
# 2       911542923333820416  山川ゆりこ《立憲民主党 りっけん 埼玉3区  yamakawa_yuriko
# 3                 12392332                  家入 一真             hbkr
# 4                 43028151                   吉田雄人      YoshidaYuto
# ...                    ...                    ...              ...
# 282978           133169129                   None             None
# 282979           154140654                   None             None
# 282980           108003321                   None             None
# 282981           185597946                   None             None
# 282982           327155709                   None             None
#
#                            location protected  followers_count  friends_count  \
# 0                           大阪府岸和田市     False           2663.0         2455.0
# 1       兵庫県神戸市中央区八幡通4-2-14トロア神戸ビル4F     False           4107.0         2382.0
# 2                        埼玉 草加市・越谷市     False           2313.0          104.0
# 3                                       False         258141.0         4020.0
# 4                                       False           6671.0         3117.0
# ...                             ...       ...              ...            ...
# 282978                         None      None              NaN            NaN
# 282979                         None      None              NaN            NaN
# 282980                         None      None              NaN            NaN
# 282981                         None      None              NaN            NaN
# 282982                         None      None              NaN            NaN
#
#         listed_count
# 0              216.0
# 1              253.0
# 2               89.0
# 3             4566.0
# 4              530.0
# ...              ...
# 282978           NaN
# 282979           NaN
# 282980           NaN
# 282981           NaN
# 282982           NaN
#
# [282983 rows x 8 columns]

# %%
rename_dict = {
    'id': 'userId:ID',
    'protected': 'protected:boolean',
    'followers_count': 'followersCount:float',
    'friends_count': 'friendsCount:float',
    'listed_count': 'listedCount:float',
    'created_at': 'createdAt:date'
}

# %%
user_df_rename = user_df.rename(columns=rename_dict)
user_df_rename[':LABEL'] = 'USER'

# %%
user_df_rename
# Out:
#                  userId:ID                   name      screen_name  \
# 0                 99227667                  米田　貴志    yonedatakashi
# 1                141513987     前衆議院議員・いさか信彦（兵庫１区）    isakanobuhiko
# 2       911542923333820416  山川ゆりこ《立憲民主党 りっけん 埼玉3区  yamakawa_yuriko
# 3                 12392332                  家入 一真             hbkr
# 4                 43028151                   吉田雄人      YoshidaYuto
# ...                    ...                    ...              ...
# 282978           133169129                   None             None
# 282979           154140654                   None             None
# 282980           108003321                   None             None
# 282981           185597946                   None             None
# 282982           327155709                   None             None
#
#                            location  \
# 0                           大阪府岸和田市
# 1       兵庫県神戸市中央区八幡通4-2-14トロア神戸ビル4F
# 2                        埼玉 草加市・越谷市
# 3
# 4
# ...                             ...
# 282978                         None
# 282979                         None
# 282980                         None
# 282981                         None
# 282982                         None
#
#                                               description protected:boolean  \
# 0       公明党岸和田市議会議員です。平成19年4月に初当選させて頂きました。市民を守る豊かな財政力を...             False
# 1       前衆議院議員・井坂信彦（神戸市中央区・灘区・東灘区）のtwitterです。本人およびスタッフ...             False
# 2       埼玉３区（草加市・越谷市）の衆議院議員です。山川ゆりこは一貫して「武力によらない平和をつくる...             False
# 3       金融包摂をつくる。CAMPFIRE代表取締役。BASE共同創業取締役。NOW, XIMERA...             False
# 4                         Glocal Government Relationz株式会社             False
# ...                                                   ...               ...
# 282978                                               None              None
# 282979                                               None              None
# 282980                                               None              None
# 282981                                               None              None
# 282982                                               None              None
#
#         followersCount:float  friendsCount:float  listedCount:float  \
# 0                     2663.0              2455.0              216.0
# 1                     4107.0              2382.0              253.0
# 2                     2313.0               104.0               89.0
# 3                   258141.0              4020.0             4566.0
# 4                     6671.0              3117.0              530.0
# ...                      ...                 ...                ...
# 282978                   NaN                 NaN                NaN
# 282979                   NaN                 NaN                NaN
# 282980                   NaN                 NaN                NaN
# 282981                   NaN                 NaN                NaN
# 282982                   NaN                 NaN                NaN
#
#                   createdAt:date :LABEL
# 0      2009-12-25 05:45:31+00:00   USER
# 1      2010-05-08 08:23:24+00:00   USER
# 2      2017-09-23 10:49:03+00:00   USER
# 3      2008-01-18 09:01:26+00:00   USER
# 4      2009-05-28 02:32:22+00:00   USER
# ...                          ...    ...
# 282978                       NaT   USER
# 282979                       NaT   USER
# 282980                       NaT   USER
# 282981                       NaT   USER
# 282982                       NaT   USER
#
# [282983 rows x 11 columns]

# %%
user_df_rename.to_csv('./data/neo4j_graph/politician_user_node.csv', index=False, quotechar='"')

# %% [markdown]
# ## relationship

# %% [markdown]
# ### category group

# %%
category_group_relationship = [
    [category_name_to_id[r[0]], group_name_to_id[r[1]]] 
    for r in set([(c[0], c[1]) for c in category_information])
]

# %%
category_group_df = pd.DataFrame(category_group_relationship, columns=[':END_ID', ':START_ID'])

# %%
category_group_df[':TYPE'] = 'BELONG'

# %%
category_group_df.to_csv('./data/neo4j_graph/politician_category_group_relationship.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-aa1af40024d2> in <module>
# ----> 1 category_group_df.iloc[:3].to_csv('./data/neo4j_graph/politician_category_group_relationship.csv', index=False)
#
# NameError: name 'category_group_df' is not defined

# %% [markdown]
# ### category user

# %%
user_screen_name_id_dict = {u['screen_name']: u['id'] for u in user_information_parsed}

# %%
category_information
# Out:
# [['政治家・議員', '日本のこころを大切にする党', 'miosugita'],
#  ['政治家・議員', '日本のこころを大切にする党', 'nakayamanariaki'],
#  ['政治家・議員', '日本のこころを大切にする党', 'nipponkokoro'],
#  ['政治家・議員', '日本のこころを大切にする党', 'masashi_nakano'],
#  ['政治家・議員', '日本維新の会', 'hiroyoshimura'],
#  ['政治家・議員', '日本維新の会', 'gogoichiro'],
#  ['政治家・議員', '日本維新の会', 'adachiyasushi'],
#  ['政治家・議員', '日本維新の会', 'maruyamahodaka'],
#  ['政治家・議員', '日本維新の会', 'loveyassy'],
#  ['政治家・議員', '日本維新の会', 'fujimaki_takesi'],
#  ['政治家・議員', '日本維新の会', 'osaka_ishin'],
#  ['政治家・議員', '日本維新の会', 'fumi_fuji'],
#  ['政治家・議員', '日本維新の会', 'asalogue'],
#  ['政治家・議員', '日本維新の会', 'toru_azuma'],
#  ['政治家・議員', '日本維新の会', 'katayama1122'],
#  ['政治家・議員', '日本維新の会', 'mikioshimoji'],
#  ['政治家・議員', '日本維新の会', 'uranoyasuto'],
#  ['政治家・議員', '日本維新の会', 'ishii_ishin'],
#  ['政治家・議員', '立憲民主党', 'pontapiranao'],
#  ['政治家・議員', '立憲民主党', 'MORIYAMAhiro'],
#  ['政治家・議員', '立憲民主党', 'waseda_yuki'],
#  ['政治家・議員', '立憲民主党', 'go_shinohara'],
#  ['政治家・議員', '立憲民主党', 'yamahanaikuo'],
#  ['政治家・議員', '立憲民主党', 'kameiakikoweb'],
#  ['政治家・議員', '立憲民主党', 'IshikawaKaori11'],
#  ['政治家・議員', '立憲民主党', 'YutaHiyoshi'],
#  ['政治家・議員', '立憲民主党', 'kondo_shoichi'],
#  ['政治家・議員', '立憲民主党', 'chinami_niigata'],
#  ['政治家・議員', '立憲民主党', 'SatoshiSatoshiA'],
#  ['政治家・議員', '立憲民主党', 'a_okamotooffice'],
#  ['政治家・議員', '立憲民主党', 'sakurai_shu'],
#  ['政治家・議員', '立憲民主党', 'kazu_okajima'],
#  ['政治家・議員', '立憲民主党', 'yamakawa_yuriko'],
#  ['政治家・議員', '立憲民主党', 'NorioKochi'],
#  ['政治家・議員', '立憲民主党', 'nagaohideki_CDP'],
#  ['政治家・議員', '立憲民主党', 'Shin1Miyakawa'],
#  ['政治家・議員', '立憲民主党', 'rikken_akamatsu'],
#  ['政治家・議員', '立憲民主党', 'michishitadaiki'],
#  ['政治家・議員', '立憲民主党', 'akutsuyukihiko'],
#  ['政治家・議員', '大阪維新の会', 'hiroyoshimura'],
#  ['政治家・議員', '大阪維新の会', 'oneosaka'],
#  ['政治家・議員', '大阪維新の会', 'asalogue'],
#  ['政治家・議員', '大阪維新の会', 'toru_azuma'],
#  ['政治家・議員', '大阪維新の会', 'YoshikaIto'],
#  ['政治家・議員', '大阪維新の会', 'sasaki_rie'],
#  ['政治家・議員', '都知事選2014', 'toshio_tamogami'],
#  ['政治家・議員', '都知事選2014', 'hbkr'],
#  ['政治家・議員', '都知事選2014', 'MasuzoeYoichi'],
#  ['政治家・議員', '都知事選2014', 'utsunomiyakenji'],
#  ['政治家・議員', '都知事選2014', 'morihirotokyo'],
#  ['政治家・議員', '都知事選2014', 'macakasaka'],
#  ['政治家・議員', '都知事選2014', 'Dr_NakaMats'],
#  ['政治家・議員', '都知事選2014', 'tocho_senkyo'],
#  ['政治家・議員', '無所属', 'higashi_kokuba'],
#  ['政治家・議員', '無所属', 'NAKADAHiroshi'],
#  ['政治家・議員', '無所属', 'hosakanobuto'],
#  ['政治家・議員', '無所属', 'yamadataro43'],
#  ['政治家・議員', '無所属', 'miyake_yukiko35'],
#  ['政治家・議員', '無所属', 'hiramatsu_osaka'],
#  ['政治家・議員', '無所属', 'shiomura'],
#  ['政治家・議員', '無所属', 'onojiro'],
#  ['政治家・議員', '無所属', 'KawadaOffice'],
#  ['政治家・議員', '無所属', 'yokokume'],
#  ['政治家・議員', '無所属', 'mitani_h'],
#  ['政治家・議員', '無所属', 'Kenji_Nakanishi'],
#  ['政治家・議員', '無所属', 'fsakura'],
#  ['政治家・議員', '無所属', 'y_yamano'],
#  ['政治家・議員', '無所属', 'matsuzawaoffice'],
